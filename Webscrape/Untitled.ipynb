# %%
import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# from seaborn import sns
from urllib.request import urlopen
from bs4 import BeautifulSoup as BS
import requests

# %%
# url = "https://www.trulia.com/for_rent/San_Diego,CA/"
# html = urlopen(url)

# %%
# soup = BeautifulSoup(html, 'lxml')
# type(soup)

# %%
# title = soup.title
# print(title)

# %%
url = 'https://www.trulia.com/for_rent/San_Diego,CA/'
agent = {"User-Agent":'Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/59.0.3071.115 Safari/537.36'}
page = requests.get(url, headers=agent)
possible_links = bs.find_all('a')
for link in possible_links:
    if link.has_attr('href'):
        print(link.attrs['href'])
print (BS(page.content, 'lxml'))
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><meta charset="utf-8"/><script>
#             window.__uspapi = function(command, version, callback) {
#               try {
#                 if (command === 'getUSPData') {
#                   var cookies = document.cookie.split(';');
#                   for (var i = 0; i < cookies.length; i++) {
#                     var cookie = cookies[i];
#                     var separatorIndex = cookie.indexOf('=');
#                     separatorIndex = separatorIndex < 0 ? cookie.length : separatorIndex;
#                     var cookie_name = decodeURIComponent(cookie.slice(0, separatorIndex).replace(/^\s+/, ''));
#                     if (cookie_name === 'usprivacy') {
#                       var uspString = decodeURIComponent(cookie.slice(separatorIndex + 1));
#                       callback({ version: version, uspString: uspString }, true);
#                       return;
#                     }
#                   }
#                 }
#               } catch (ex) {
#                 console.error(ex);
#               }
#               callback(null, false);
#             }
#
#             window.addEventListener('message', function(event) {
#               if (event && event.data && event.data.__uspapiCall
#                 && event.source && event.source.postMessage
#               ) {
#                 window.__uspapi(
#                   event.data.__uspapiCall.command,
#                   event.data.__uspapiCall.version,
#                   function(data, success) {
#                     event.source.postMessage({
#                       __uspapiReturn: {
#                         returnValue: data,
#                         success: success,
#                         callId: event.data.__uspapiCall.callId
#                       }
#                     });
#                   }
#                 );
#               }
#             }, false);
#           </script><script>
#           window.trulia = window.trulia || {};
#           trulia.analytics = trulia.analytics || {};
#           trulia.analytics.automaticTrackState = false;
#         </script><style data-styled="" data-styled-version="5.1.1">.ilIDoN{-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# data-styled.g1[id="MediaBlock__MediaContainer-ldzu2c-0"]{content:"ilIDoN,"}/*!sc*/
# .eOdfXT{margin:0 4px;}/*!sc*/
# .eOdfXT:last-child{margin-right:0;}/*!sc*/
# .eOdfXT:first-child{margin-left:0;}/*!sc*/
# .bWYwlH{margin:0 8px;}/*!sc*/
# .bWYwlH:last-child{margin-right:0;}/*!sc*/
# .bWYwlH:first-child{margin-left:0;}/*!sc*/
# .drKwQp{margin:0 2px;}/*!sc*/
# .drKwQp:last-child{margin-right:0;}/*!sc*/
# .drKwQp:first-child{margin-left:0;}/*!sc*/
# .cbztua{-webkit-flex:1 1 0px;-ms-flex:1 1 0px;flex:1 1 0px;width:100%;margin:0 8px;}/*!sc*/
# .cbztua:last-child{margin-right:0;}/*!sc*/
# .cbztua:first-child{margin-left:0;}/*!sc*/
# .jpUaGQ{margin:0 8px;overflow:hidden;}/*!sc*/
# .jpUaGQ:last-child{margin-right:0;}/*!sc*/
# .jpUaGQ:first-child{margin-left:0;}/*!sc*/
# .eMFfAi{margin:0 2px;overflow:hidden;}/*!sc*/
# .eMFfAi:last-child{margin-right:0;}/*!sc*/
# .eMFfAi:first-child{margin-left:0;}/*!sc*/
# data-styled.g2[id="MediaBlock__MediaContent-ldzu2c-1"]{content:"eOdfXT,bWYwlH,drKwQp,cbztua,jpUaGQ,eMFfAi,"}/*!sc*/
# .gbHoxB{width:16px !important;height:16px !important;display:inline-block;font-size:0;}/*!sc*/
# .gbHoxB .svg{width:16px;}/*!sc*/
# .gbHoxB .svg{height:16px;}/*!sc*/
# .gbHoxB path{fill:rgb(134,144,153);}/*!sc*/
# .BCzkn{width:24px !important;height:24px !important;display:inline-block;font-size:0;}/*!sc*/
# .BCzkn .svg{width:24px;}/*!sc*/
# .BCzkn .svg{height:24px;}/*!sc*/
# .BCzkn path{fill:rgb(255,255,255);}/*!sc*/
# .AphAU{width:24px !important;height:24px !important;display:inline-block;font-size:0;}/*!sc*/
# .AphAU .svg{width:24px;}/*!sc*/
# .AphAU .svg{height:24px;}/*!sc*/
# .AphAU path{fill:rgb(0,120,130);}/*!sc*/
# .gKjLnc{width:24px !important;height:24px !important;display:inline-block;font-size:0;}/*!sc*/
# .gKjLnc .svg{width:24px;}/*!sc*/
# .gKjLnc .svg{height:24px;}/*!sc*/
# .gKjLnc path{fill:rgb(59,65,68);}/*!sc*/
# .dZfmwo{width:16px !important;height:24px !important;display:inline-block;font-size:0;}/*!sc*/
# .dZfmwo .svg{width:16px;}/*!sc*/
# .dZfmwo .svg{height:24px;}/*!sc*/
# .dZfmwo path{fill:rgb(0,120,130);}/*!sc*/
# .bBQvTY{width:20px !important;height:20px !important;display:inline-block;font-size:0;}/*!sc*/
# .bBQvTY .svg{width:20px;}/*!sc*/
# .bBQvTY .svg{height:20px;}/*!sc*/
# .bBQvTY path{fill:rgb(0,120,130);}/*!sc*/
# .llPhfs{width:16px !important;height:16px !important;display:inline-block;font-size:0;}/*!sc*/
# .llPhfs .svg{width:16px;}/*!sc*/
# .llPhfs .svg{height:16px;}/*!sc*/
# .llPhfs path{fill:rgb(0,120,130);}/*!sc*/
# .kRvEfs{width:20px !important;height:20px !important;display:inline-block;font-size:0;}/*!sc*/
# .kRvEfs .svg{width:20px;}/*!sc*/
# .kRvEfs .svg{height:20px;}/*!sc*/
# .kRvEfs path{fill:rgb(59,65,68);}/*!sc*/
# data-styled.g3[id="getUiSvgContainer__SvgContainer-sc-12y8qp5-0"]{content:"gbHoxB,BCzkn,AphAU,gKjLnc,dZfmwo,bBQvTY,llPhfs,kRvEfs,"}/*!sc*/
# .fUDZSu{font-weight:bold;}/*!sc*/
# .hpggbg{font-size:14px;line-height:1.43;}/*!sc*/
# .hpggbg .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:20.02px;width:20.02px;}/*!sc*/
# .hrfbXr{color:rgb(0,120,130);}/*!sc*/
# data-styled.g5[id="Text__TextBase-sc-1i9uasc-0"]{content:"fUDZSu,hpggbg,iWpBCo,hrfbXr,"}/*!sc*/
# .jXLtij{font-weight:bold;font-size:20px;line-height:1.2;}/*!sc*/
# .jXLtij .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:24px;width:24px;}/*!sc*/
# .fBrNds{color:rgb(0,120,130);}/*!sc*/
# .bilCLO{font-weight:bold;font-size:20px;line-height:1.2;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;}/*!sc*/
# .bilCLO .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:24px;width:24px;}/*!sc*/
# .SSeMC{font-size:16px;line-height:1.5;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;}/*!sc*/
# .SSeMC .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:24px;width:24px;}/*!sc*/
# .cKVrTx{font-weight:bold;font-size:14px;line-height:1.43;}/*!sc*/
# .cKVrTx .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:20.02px;width:20.02px;}/*!sc*/
# .AuUdo{color:rgb(134,144,153);font-size:12px;line-height:1.33;}/*!sc*/
# .AuUdo .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:15.96px;width:15.96px;}/*!sc*/
# .htlzvC{font-weight:bold;font-size:14px;line-height:1.43;}/*!sc*/
# @media (min-width:376px){.htlzvC{font-size:14px;}}/*!sc*/
# @media (min-width:570px){.htlzvC{font-size:14px;}}/*!sc*/
# @media (min-width:768px){.htlzvC{font-size:16px;}}/*!sc*/
# @media (min-width:376px){.htlzvC{line-height:1.43;}}/*!sc*/
# @media (min-width:570px){.htlzvC{line-height:1.43;}}/*!sc*/
# @media (min-width:768px){.htlzvC{line-height:1.5;}}/*!sc*/
# .htlzvC .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:20.02px;width:20.02px;}/*!sc*/
# @media (min-width:376px){.htlzvC .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:20.02px;}}/*!sc*/
# @media (min-width:570px){.htlzvC .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:20.02px;}}/*!sc*/
# @media (min-width:768px){.htlzvC .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:24px;}}/*!sc*/
# @media (min-width:376px){.htlzvC .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{width:20.02px;}}/*!sc*/
# @media (min-width:570px){.htlzvC .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{width:20.02px;}}/*!sc*/
# @media (min-width:768px){.htlzvC .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{width:24px;}}/*!sc*/
# .cKQvhd{font-weight:bold;}/*!sc*/
# data-styled.g7[id="Text__TextContainerBase-sc-1i9uasc-1"]{content:"jXLtij,fOTDnX,fBrNds,bilCLO,SSeMC,cKVrTx,AuUdo,htlzvC,cKQvhd,"}/*!sc*/
# .dVAHkn{padding:8px 16px 8px 16px;}/*!sc*/
# .hHdhNP{padding:0 8px 0 0;}/*!sc*/
# .iizeRt{padding:0 0 0 2px;}/*!sc*/
# .bjJlqt{padding:4px 2px 0 0;}/*!sc*/
# .hPUFef{padding:8px 0 0 0;}/*!sc*/
# .hHdjtD{padding:0 4px 0 0;}/*!sc*/
# .knveJa{padding:0 0 32px 0;}/*!sc*/
# .ifaOfH{padding:16px 0 16px 0;}/*!sc*/
# data-styled.g8[id="Padding-sc-1d43y5s-0"]{content:"dVAHkn,hHdhNP,iizeRt,bjJlqt,hPUFef,hHdjtD,knveJa,ifaOfH,"}/*!sc*/
# .cTxnRz{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;overflow:auto;-webkit-overflow-scrolling:touch;}/*!sc*/
# @media (max-width:47.9375em){.cTxnRz{display:block;}}/*!sc*/
# data-styled.g10[id="FlexContainers__Rows-sc-1ezkc0e-0"]{content:"cTxnRz,"}/*!sc*/
# .uIMvr{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;}/*!sc*/
# data-styled.g12[id="FlexContainers__Columns-sc-1ezkc0e-2"]{content:"uIMvr,"}/*!sc*/
# .dIBGmt{width:70px;height:24px;display:inline-block;line-height:0;}/*!sc*/
# .dIBGmt .svg{width:70px;}/*!sc*/
# .dIBGmt .svg{height:24px;}/*!sc*/
# .cnYhHF{width:20px;height:20px;display:inline-block;line-height:0;}/*!sc*/
# .cnYhHF .svg{width:20px;}/*!sc*/
# .cnYhHF .svg{height:20px;}/*!sc*/
# data-styled.g21[id="getSvgContainer__SvgContainer-sc-30hfky-0"]{content:"dIBGmt,cnYhHF,"}/*!sc*/
# .enfmDl{margin:0;border-radius:8px;border-width:1px;border-style:solid;cursor:pointer;display:inline-block;color:rgb(59,65,68);text-align:center;font-weight:bold;-webkit-transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;white-space:nowrap;font-size:16px;line-height:1.5;padding:8px 16px;}/*!sc*/
# .enfmDl path{-webkit-transition:fill 0.1s;transition:fill 0.1s;}/*!sc*/
# .enfmDl .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:24px;width:24px;}/*!sc*/
# .enfmDl::-moz-focus-inner{border:0;}/*!sc*/
# .enfmDl[class~='focus'],.enfmDl:focus{outline:none;}/*!sc*/
# .enfmDl[disabled]{cursor:none;pointer-events:none;}/*!sc*/
# .bfaurZ{margin:0;border-radius:8px;border-width:1px;border-style:solid;cursor:pointer;display:inline-block;color:rgb(59,65,68);text-align:center;font-weight:bold;-webkit-transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;white-space:nowrap;font-size:16px;line-height:1.5;padding:8px 16px;width:100%;}/*!sc*/
# .bfaurZ path{-webkit-transition:fill 0.1s;transition:fill 0.1s;}/*!sc*/
# .bfaurZ .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:24px;width:24px;}/*!sc*/
# .bfaurZ::-moz-focus-inner{border:0;}/*!sc*/
# .bfaurZ[class~='focus'],.bfaurZ:focus{outline:none;}/*!sc*/
# .bfaurZ[disabled]{cursor:none;pointer-events:none;}/*!sc*/
# data-styled.g22[id="ButtonBase-c2s2ot-0"]{content:"enfmDl,bfaurZ,"}/*!sc*/
# .ijPmHb{margin:0;border-radius:8px;border-width:1px;border-style:solid;cursor:pointer;display:inline-block;color:rgb(59,65,68);text-align:center;font-weight:bold;-webkit-transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;white-space:nowrap;font-size:16px;line-height:1.5;padding:8px 16px;color:rgb(59,65,68);background-color:rgb(255,255,255);border-color:rgb(205,209,212);}/*!sc*/
# .ijPmHb path{-webkit-transition:fill 0.1s;transition:fill 0.1s;}/*!sc*/
# .ijPmHb .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:24px;width:24px;}/*!sc*/
# .ijPmHb::-moz-focus-inner{border:0;}/*!sc*/
# .ijPmHb[class~='focus'],.ijPmHb:focus{outline:none;}/*!sc*/
# .ijPmHb[disabled]{cursor:none;pointer-events:none;}/*!sc*/
# .ijPmHb:hover,.ijPmHb[class~='hover']{color:rgb(59,65,68);background-color:rgb(232,233,234);border-color:transparent;}/*!sc*/
# .ijPmHb[class~='focus'],.ijPmHb:focus{color:rgb(59,65,68);background-color:rgb(255,255,255);border-color:rgb(134,144,153);}/*!sc*/
# .ijPmHb[class~='active'],.ijPmHb:active{color:rgb(255,255,255);background-color:rgb(134,144,153);border-color:transparent;}/*!sc*/
# .ijPmHb[class~='active'] .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path,.ijPmHb:active .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(255,255,255);}/*!sc*/
# .ijPmHb[disabled]{color:rgb(205,209,212);background-color:rgb(245,246,247);border-color:rgb(205,209,212);}/*!sc*/
# .ijPmHb[disabled] .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(205,209,212);}/*!sc*/
# data-styled.g32[id="Button-sc-1dzv3kc-0"]{content:"ijPmHb,"}/*!sc*/
# .eVbKXM{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-left:-8px;margin-right:-8px;margin-top:-16px;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;}/*!sc*/
# .eVbKXM > .Grid__CellBox-sc-5ig2n4-0{border-style:solid;border-color:transparent;border-width:16px 8px 0px 8px;}/*!sc*/
# data-styled.g51[id="Grid__GridContainer-sc-5ig2n4-1"]{content:"eVbKXM,"}/*!sc*/
# .gdZMni{display:block;border-style:solid !important;border-color:rgb(205,209,212);border-width:0 0 1px 0;}/*!sc*/
# .bEtpBg{display:block;}/*!sc*/
# @media (min-width:376px){.bEtpBg{display:block;}}/*!sc*/
# @media (min-width:570px){.bEtpBg{display:block;}}/*!sc*/
# @media (min-width:768px){.bEtpBg{display:none;}}/*!sc*/
# @media (min-width:993px){.bEtpBg{display:none;}}/*!sc*/
# .cGSrLE{display:none;}/*!sc*/
# @media (min-width:376px){.cGSrLE{display:none;}}/*!sc*/
# @media (min-width:570px){.cGSrLE{display:none;}}/*!sc*/
# @media (min-width:768px){.cGSrLE{display:block;}}/*!sc*/
# @media (min-width:993px){.cGSrLE{display:none;}}/*!sc*/
# .bHnyFL{display:inline-block;display:inline-block;}/*!sc*/
# .jDcCbK{display:block;}/*!sc*/
# data-styled.g53[id="Box-sc-8ox7qa-0"]{content:"gdZMni,bEtpBg,cGSrLE,bHnyFL,jDcCbK,"}/*!sc*/
# .eAlroL{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:100%;height:64px;margin:0;padding:0 16px 0 16px;padding:0 calc(16px + env(safe-area-inset-right)) 0 calc(16px + env(safe-area-inset-left));background-color:rgb(255,255,255);position:relative;z-index:100;font-size:15px;border-bottom:1px solid rgb(232,233,234);}/*!sc*/
# @media (max-width:62em){.eAlroL{padding:0 12px;}}/*!sc*/
# data-styled.g59[id="Navbar__Nav-sky7mr-0"]{content:"eAlroL,"}/*!sc*/
# .cSuaGC{margin-left:16px;margin-top:8px;cursor:pointer;border:none;background-color:rgb(255,255,255);}/*!sc*/
# @media (max-width:62em){.cSuaGC{margin-right:-10px;margin-left:2px;}}/*!sc*/
# data-styled.g60[id="Navbar__NavbarMobileMenuToggle-sky7mr-1"]{content:"cSuaGC,"}/*!sc*/
# .lmeUPp{-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;padding:16px 24px 16px 0;}/*!sc*/
# @media (max-width:62em){.lmeUPp{padding:20px 12px 12px 12px;}}/*!sc*/
# data-styled.g61[id="Navbar__LogoContainer-sky7mr-2"]{content:"lmeUPp,"}/*!sc*/
# .jrbzWH{cursor:pointer;display:inline;}/*!sc*/
# .jrbzWH[role='button']:focus,.jrbzWH[role='button']:active{outline:none;box-shadow:0 0 0 1px rgb(134,144,153);}/*!sc*/
# data-styled.g63[id="BoxButton-sc-100k4t8-0"]{content:"jrbzWH,"}/*!sc*/
# .dTxqov{line-height:1;color:inherit;}/*!sc*/
# data-styled.g64[id="UiButton-s4vt60-0"]{content:"dTxqov,"}/*!sc*/
# .dzajPJ{color:rgb(59,65,68);-webkit-transition:background 0.15s ease-in-out;transition:background 0.15s ease-in-out;position:relative;}/*!sc*/
# .dzajPJ > a,.dzajPJ > span,.dzajPJ > button:not(.Button-sc-1dzv3kc-0){cursor:pointer;padding:8px 16px 8px 16px;color:rgb(59,65,68);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border-radius:8px;}/*!sc*/
# .dzajPJ > a:focus svg path,.dzajPJ > span:focus svg path,.dzajPJ > button:not(.Button-sc-1dzv3kc-0):focus svg path{fill:rgb(59,65,68);}/*!sc*/
# .dzajPJ svg{margin-top:-1px;}/*!sc*/
# .dzajPJ > span{cursor:default;}/*!sc*/
# .dzajPJ:hover > a,.dzajPJ:hover > span,.dzajPJ:hover > button:not(.Button-sc-1dzv3kc-0){color:rgb(255,255,255);background-color:rgb(0,120,130);}/*!sc*/
# .dzajPJ:hover > a svg path,.dzajPJ:hover > span svg path,.dzajPJ:hover > button:not(.Button-sc-1dzv3kc-0) svg path{fill:rgb(255,255,255);}/*!sc*/
# .dzajPJ:hover > ul{display:block;}/*!sc*/
# .dzajPJ:hover > ul::before{display:block;position:absolute;content:'';width:100%;height:15px;top:-15px;}/*!sc*/
# .dzajPJ ul{display:none;position:absolute;top:45px;background:rgb(255,255,255);border-radius:4px;box-shadow:0 2px 4px 0 rgba(59,65,68,0.5);padding:4px 0;}/*!sc*/
# .dzajPJ ul a,.dzajPJ ul button{color:rgb(59,65,68);white-space:nowrap;display:block;}/*!sc*/
# .dzajPJ ul a:hover,.dzajPJ ul button:hover{color:rgb(59,65,68);background-color:rgb(232,233,234);}/*!sc*/
# data-styled.g71[id="NavbarItem-sc-1kjsgse-0"]{content:"dzajPJ,"}/*!sc*/
# .gJOvqm{margin:0;border-radius:8px;border-width:1px;border-style:solid;cursor:pointer;display:inline-block;color:rgb(59,65,68);text-align:center;font-weight:bold;-webkit-transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;white-space:nowrap;font-size:16px;line-height:1.5;padding:8px 16px;color:rgb(59,65,68);background-color:rgb(255,255,255);border-color:transparent;}/*!sc*/
# .gJOvqm path{-webkit-transition:fill 0.1s;transition:fill 0.1s;}/*!sc*/
# .gJOvqm .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:24px;width:24px;}/*!sc*/
# .gJOvqm::-moz-focus-inner{border:0;}/*!sc*/
# .gJOvqm[class~='focus'],.gJOvqm:focus{outline:none;}/*!sc*/
# .gJOvqm[disabled]{cursor:none;pointer-events:none;}/*!sc*/
# .gJOvqm .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(59,65,68);}/*!sc*/
# .gJOvqm[class~='hover'],.gJOvqm:hover{color:rgb(255,255,255);background-color:rgb(0,120,130);border-color:transprant;}/*!sc*/
# .gJOvqm[class~='hover'] .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path,.gJOvqm:hover .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(255,255,255);}/*!sc*/
# .gJOvqm[class~='focus'],.gJOvqm:focus{color:rgb(0,120,130);background-color:rgb(224,247,248);border-color:rgb(0,120,130);}/*!sc*/
# .gJOvqm[class~='focus'] .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path,.gJOvqm:focus .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(0,120,130);}/*!sc*/
# .gJOvqm[class~='active'],.gJOvqm:active{color:rgb(59,65,68);background-color:rgb(232,233,234);border-color:transparent;box-shadow:none;}/*!sc*/
# .gJOvqm[class~='active'] .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path,.gJOvqm:active .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(59,65,68);}/*!sc*/
# .gJOvqm[disabled]{color:rgb(205,209,212);background-color:rgb(245,246,247);border-color:rgb(205,209,212);box-shadow:none;}/*!sc*/
# .gJOvqm[disabled] .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(205,209,212);}/*!sc*/
# data-styled.g76[id="GlobalNavigationButton-x5u2ga-0"]{content:"gJOvqm,"}/*!sc*/
# .kgdOJe li{display:inline-block;border-style:none;margin-right:8px;}/*!sc*/
# .kgdOJe li:last-child{margin:0;}/*!sc*/
# data-styled.g77[id="List__ListContainer-sc-1mezygb-0"]{content:"eXLjRu,kgdOJe,"}/*!sc*/
# .dHAjsq{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding-left:4px;-webkit-flex:0 1 420px;-ms-flex:0 1 420px;flex:0 1 420px;}/*!sc*/
# .dHAjsq:first-of-type{padding-left:0;}/*!sc*/
# @media (min-width:1060px){}/*!sc*/
# @media (min-width:1240px){}/*!sc*/
# @media (max-width:62em){.dHAjsq{-webkit-flex:1 1 auto;-ms-flex:1 1 auto;flex:1 1 auto;}}/*!sc*/
# data-styled.g82[id="NavbarContainer__SearchBarSection-sc-15svuwa-4"]{content:"dHAjsq,"}/*!sc*/
# .irVkmO{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding-left:4px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .irVkmO:first-of-type{padding-left:0;}/*!sc*/
# @media (min-width:1060px){}/*!sc*/
# @media (min-width:1240px){}/*!sc*/
# @media (max-width:1240px){.irVkmO{display:none;}}/*!sc*/
# @media (max-width:1060px){.irVkmO{display:none;}}/*!sc*/
# data-styled.g83[id="NavbarContainer__NavLinkSection-sc-15svuwa-5"]{content:"irVkmO,"}/*!sc*/
# .ekDFQx{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding-left:4px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;-webkit-flex:1 0 auto;-ms-flex:1 0 auto;flex:1 0 auto;}/*!sc*/
# .ekDFQx:first-of-type{padding-left:0;}/*!sc*/
# @media (min-width:1060px){}/*!sc*/
# @media (min-width:1240px){}/*!sc*/
# @media (max-width:62em){.ekDFQx{display:none;}}/*!sc*/
# data-styled.g84[id="NavbarContainer__UserButtonsSection-sc-15svuwa-6"]{content:"ekDFQx,"}/*!sc*/
# .foMLyf{border:1px solid rgb(245,246,247);border-radius:8px;background-color:rgb(245,246,247);padding:8px 64px 8px 16px;color:rgb(59,65,68);font-size:16px;line-height:1.5;width:100%;height:42px;-webkit-transition:width 0.35s ease;transition:width 0.35s ease;display:inline-block;-webkit-appearance:none;-moz-appearance:none;appearance:none;}/*!sc*/
# .foMLyf.react-autosuggest__input--open{border:1px solid rgb(245,246,247);border-radius:8px;border-bottom-left-radius:0px;border-bottom-right-radius:0px;border-bottom:none;}/*!sc*/
# .foMLyf .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:24px;width:24px;}/*!sc*/
# .foMLyf::-webkit-input-placeholder{color:rgb(134,144,153);}/*!sc*/
# .foMLyf::-moz-placeholder{color:rgb(134,144,153);}/*!sc*/
# .foMLyf:-ms-input-placeholder{color:rgb(134,144,153);}/*!sc*/
# .foMLyf::placeholder{color:rgb(134,144,153);}/*!sc*/
# .foMLyf[placeholder]{text-overflow:ellipsis;}/*!sc*/
# .foMLyf::-ms-clear{display:none;}/*!sc*/
# .foMLyf:focus{border-color:rgb(205,209,212);background-color:rgb(255,255,255);outline:none;}/*!sc*/
# .foMLyf:focus{padding-right:80px;}/*!sc*/
# data-styled.g88[id="LocationAutosuggestInput__Input-sc-113k62k-0"]{content:"foMLyf,"}/*!sc*/
# .kyOPmV{position:relative;}/*!sc*/
# data-styled.g89[id="LocationAutosuggestInput__InputContainer-sc-113k62k-1"]{content:"kyOPmV,"}/*!sc*/
# .ipfVzQ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;position:absolute;right:48px;top:0;height:100%;padding:12px;}/*!sc*/
# input:not(:focus) + .ipfVzQ{display:none;}/*!sc*/
# data-styled.g90[id="LocationAutosuggestInput__RightInnerIcon-sc-113k62k-2"]{content:"ipfVzQ,"}/*!sc*/
# .fIhkCx{position:absolute;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;right:0;top:0;height:100%;min-width:42px;cursor:pointer;background-color:rgb(217,60,35);padding:9px 12px;border-bottom-right-radius:8px;border-top-right-radius:8px;-webkit-transition:background-color 0.15s ease;transition:background-color 0.15s ease;}/*!sc*/
# .react-autosuggest__input--open ~ .fIhkCx{border-bottom-right-radius:0;}/*!sc*/
# .fIhkCx:hover{background-color:rgb(156,17,20);}/*!sc*/
# data-styled.g91[id="LocationAutosuggestInput__RightIcon-sc-113k62k-3"]{content:"fIhkCx,"}/*!sc*/
# .iFFfWd{border:1px solid rgb(205,209,212);border-top:none;border-bottom-right-radius:8px;border-bottom-left-radius:8px;position:absolute;width:100%;background:white;-webkit-transition:width 0.35s ease;transition:width 0.35s ease;max-height:50vh;overflow:auto;-webkit-overflow-scrolling:touch;opacity:0;}/*!sc*/
# data-styled.g92[id="LocationAutosuggestDrodown__LocationAutosuggestDropdown-sc-1qu0vk4-0"]{content:"iFFfWd,"}/*!sc*/
# .dgWewM{position:relative;width:100%;-webkit-transition:width 0.35s ease;transition:width 0.35s ease;}/*!sc*/
# .dgWewM .react-autosuggest__suggestion--first .LocationAutosuggestDrodown__ItemContainer-sc-1qu0vk4-2{border-top:1px solid rgb(205,209,212);}/*!sc*/
# .dgWewM .react-autosuggest__section-title + .react-autosuggest__suggestions-list > .react-autosuggest__suggestion--first .LocationAutosuggestDrodown__ItemContainer-sc-1qu0vk4-2{border-top:none;}/*!sc*/
# data-styled.g95[id="LocationAutosuggestDrodown__LocationAutosuggestBoxContainer-sc-1qu0vk4-3"]{content:"dgWewM,"}/*!sc*/
# .jBXuRq{color:rgb(59,65,68);}/*!sc*/
# .jBXuRq:hover{color:rgb(0,120,130);}/*!sc*/
# @media (max-width:23.4375em){.jBXuRq{line-height:25px;}}/*!sc*/
# data-styled.g96[id="FooterAnchor__Anchor-b00yg-0"]{content:"jBXuRq,"}/*!sc*/
# .fcMFBM{padding:16px env(safe-area-inset-right) env(safe-area-inset-bottom) env(safe-area-inset-left);font-size:10px;line-height:1.6;}/*!sc*/
# .fcMFBM .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:16px;width:16px;}/*!sc*/
# data-styled.g97[id="Copyright__Container-crgciy-0"]{content:"fcMFBM,"}/*!sc*/
# .COwsW{padding:16px env(safe-area-inset-right) 16px env(safe-area-inset-left);font-size:12px;line-height:1.33;}/*!sc*/
# .COwsW .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:15.96px;width:15.96px;}/*!sc*/
# @media (max-width:23.4375em){.COwsW{line-height:22px;}}/*!sc*/
# data-styled.g99[id="Accessibility__Container-mmbqg0-0"]{content:"COwsW,"}/*!sc*/
# .dAa-Djg{padding:0;font-size:12px;line-height:1.33;}/*!sc*/
# .dAa-Djg .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:15.96px;width:15.96px;}/*!sc*/
# data-styled.g100[id="Footer__FooterContainer-sc-1vgcaho-0"]{content:"dAa-Djg,"}/*!sc*/
# .kpSvup{color:rgb(59,65,68);padding:2px 0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .kpSvup:hover{color:rgb(0,120,130);}/*!sc*/
# .kpSvup div{padding-right:24px;}/*!sc*/
# @media (max-width:47.9375em){.kpSvup{display:inline;}.kpSvup:after{content:' • ';}.kpSvup:last-child:after{content:'';}}/*!sc*/
# @media (max-width:23.4375em){.kpSvup{line-height:25px;}}/*!sc*/
# .icOKBT{color:rgb(59,65,68);padding:2px 0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:none;}/*!sc*/
# .icOKBT:hover{color:rgb(0,120,130);}/*!sc*/
# .icOKBT div{padding-right:24px;}/*!sc*/
# @media (max-width:23.4375em){.icOKBT{line-height:25px;}}/*!sc*/
# data-styled.g101[id="LinkColumn__Link-qxr6c7-0"]{content:"kpSvup,icOKBT,"}/*!sc*/
# .blAOoT{padding:32px 0 8px 0;}/*!sc*/
# @media (min-width:48em){.blAOoT{padding:2px 0;}}/*!sc*/
# .blAOoT a{color:rgb(59,65,68);}/*!sc*/
# .blAOoT a:hover{color:rgb(0,120,130);}/*!sc*/
# data-styled.g102[id="LinkColumn__LinkColumnHeading-qxr6c7-1"]{content:"blAOoT,"}/*!sc*/
# .bbQBEN{position:relative;cursor:pointer;color:rgb(0,173,187);font-size:12px;line-height:1.33;padding:0;background:none;border:none;}/*!sc*/
# .bbQBEN .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:15.96px;width:15.96px;}/*!sc*/
# data-styled.g103[id="LinkColumn__ToggleMenuButton-qxr6c7-2"]{content:"bbQBEN,"}/*!sc*/
# .fEtIVd{-webkit-flex:1 1 0px;-ms-flex:1 1 0px;flex:1 1 0px;margin-left:8px;}/*!sc*/
# .fEtIVd:first-child{margin-left:0;}/*!sc*/
# @media (max-width:47.9375em){.fEtIVd{-webkit-flex:1 0 auto;-ms-flex:1 0 auto;flex:1 0 auto;margin-left:0;}}/*!sc*/
# data-styled.g104[id="LinkColumn__Column-qxr6c7-3"]{content:"fEtIVd,"}/*!sc*/
# .biLLuz{padding:0 env(safe-area-inset-right) 0 env(safe-area-inset-left);}/*!sc*/
# data-styled.g105[id="NavigationSecondary__Container-sc-12kqh3d-0"]{content:"biLLuz,"}/*!sc*/
# .bvFaUP{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;padding:0 0 24px;}/*!sc*/
# @media (max-width:47.9375em){.bvFaUP{-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}}/*!sc*/
# data-styled.g106[id="NavigationSecondary__Inner-sc-12kqh3d-1"]{content:"bvFaUP,"}/*!sc*/
# .ckOdDw{padding:0 env(safe-area-inset-right) 0 env(safe-area-inset-left);}/*!sc*/
# data-styled.g107[id="FooterLinkList__Container-sc-1hgdfiw-0"]{content:"ckOdDw,"}/*!sc*/
# .iypLcs{padding:0 8px 0 0;}/*!sc*/
# data-styled.g108[id="FooterLinkList__LinkLabel-sc-1hgdfiw-1"]{content:"iypLcs,"}/*!sc*/
# .hFZWdr{list-style:none;display:inline-block;margin:0;padding:16px 0 16px;}/*!sc*/
# .hFZWdr li{display:inline;}/*!sc*/
# .hFZWdr li + li::before{content:'•';padding:0 4px;}/*!sc*/
# data-styled.g109[id="FooterLinkList__LinkList-sc-1hgdfiw-2"]{content:"hFZWdr,"}/*!sc*/
# .lprqrI{width:100%;height:64px;}/*!sc*/
# .lprqrI > *{z-index:100;position:fixed;border-bottom:none;}/*!sc*/
# data-styled.g116[id="SearchResultsHeader__HeaderContainer-sc-1n45ts4-0"]{content:"lprqrI,"}/*!sc*/
# .fwqQcM{position:absolute;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;height:100%;}/*!sc*/
# data-styled.g121[id="Tiles__TileBackground-wy0px0-0"]{content:"fwqQcM,"}/*!sc*/
# .DEbKY{background-color:rgb(232,233,234);position:relative;border-radius:8px;overflow:hidden;cursor:pointer;width:100%;height:100%;}/*!sc*/
# @media (hover:hover){.DEbKY{-webkit-mask-image:-webkit-radial-gradient(white,black);}.DEbKY > .Tiles__TileBackground-wy0px0-0{-webkit-transition:-webkit-transform 0.45s cubic-bezier(0.645,0.045,0.355,1);-webkit-transition:transform 0.45s cubic-bezier(0.645,0.045,0.355,1);transition:transform 0.45s cubic-bezier(0.645,0.045,0.355,1);}.DEbKY:hover > .Tiles__TileBackground-wy0px0-0{-webkit-transform:scale(1.1);-ms-transform:scale(1.1);transform:scale(1.1);}}/*!sc*/
# data-styled.g122[id="Tiles__TileContainer-wy0px0-1"]{content:"DEbKY,"}/*!sc*/
# .gSCUfD{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;padding:2px 8px;border-radius:4px;background-color:rgb(232,233,234);cursor:default;}/*!sc*/
# .gSCUfD:focus{outline:none;box-shadow:0 0 1px 1px rgb(134,144,153);}/*!sc*/
# data-styled.g130[id="Tag__TagBase-l0an8r-1"]{content:"gSCUfD,"}/*!sc*/
# .izKyiU{width:100%;display:inline-block;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;position:relative;font-weight:bold;width:unset;border-radius:8px;background-color:rgb(255,255,255);padding:8px;outline:none;-webkit-transition:box-shadow 0.15s ease,border-color 0.15s ease;transition:box-shadow 0.15s ease,border-color 0.15s ease;}/*!sc*/
# .izKyiU:focus,.izKyiU:focus-within{border-color:rgb(0,173,187);box-shadow:0 0 0 2px rgb(0,120,130);}/*!sc*/
# data-styled.g139[id="Select__SelectContainer-sc-1wiporl-0"]{content:"izKyiU,"}/*!sc*/
# .gpXBeM{position:absolute;opacity:0;width:100%;height:100%;top:0;left:0;right:0;bottom:0;cursor:pointer;-webkit-appearance:none;font-size:16px;line-height:1.5;}/*!sc*/
# .gpXBeM .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:24px;width:24px;}/*!sc*/
# data-styled.g140[id="Select__NativeSelect-sc-1wiporl-1"]{content:"gpXBeM,"}/*!sc*/
# .hQvvnw{min-width:224px;width:224px;width:100%;height:100%;}/*!sc*/
# .hQvvnw a,.hQvvnw a:hover{color:inherit;}/*!sc*/
# data-styled.g145[id="PropertyCard__PropertyCardContainer-sc-1ush98q-2"]{content:"hQvvnw,"}/*!sc*/
# .gtWlvY{object-fit:cover;width:100%;height:100%;}/*!sc*/
# data-styled.g146[id="Picture__Image-ktdqlh-0"]{content:"gtWlvY,"}/*!sc*/
# .dOtfwv{height:100%;width:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# data-styled.g147[id="Picture__PictureContainer-ktdqlh-1"]{content:"dOtfwv,"}/*!sc*/
# .eZfYRv{min-width:44px;min-height:44px;width:44px;height:44px;overflow:visible;-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}/*!sc*/
# data-styled.g149[id="IconButton-fejjl6-0"]{content:"eZfYRv,"}/*!sc*/
# .MtSAM{margin-right:4px;text-transform:uppercase;background-color:rgb(255,255,255);color:rgb(59,65,68);font-size:12px;line-height:1.33;padding:2px 4px;}/*!sc*/
# .MtSAM .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:15.96px;width:15.96px;}/*!sc*/
# data-styled.g150[id="PropertyTag-sc-1oqnx2r-0"]{content:"MtSAM,"}/*!sc*/
# .brTJKV{position:relative;z-index:0;height:calc(100% - 142px);}/*!sc*/
# data-styled.g159[id="PropertyCardMedia__PropertyCardMediaContainer-qf4uhf-0"]{content:"brTJKV,"}/*!sc*/
# .hHhujd{display:block;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:80%;height:19px;overflow:hidden;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;position:absolute;top:8px;left:8px;}/*!sc*/
# data-styled.g160[id="PropertyCardMedia__PropertyTagsContainer-qf4uhf-1"]{content:"hHhujd,"}/*!sc*/
# .jitevD{position:absolute;top:0;right:0;z-index:1;}/*!sc*/
# data-styled.g163[id="PropertyCardMedia__SaveHomeButtonContainer-qf4uhf-4"]{content:"jitevD,"}/*!sc*/
# .jXRozS{min-height:160px;}/*!sc*/
# data-styled.g164[id="PropertyCardMedia__PhotoTileContainer-qf4uhf-5"]{content:"jXRozS,"}/*!sc*/
# .jGMSsG{background-color:rgb(255,255,255);border:1px solid rgb(232,233,234);border-radius:8px;padding:0;}/*!sc*/
# data-styled.g166[id="Card-yrmhiy-0"]{content:"jGMSsG,"}/*!sc*/
# .hOmnBy{color:rgb(0,120,130);background-color:rgb(255,255,255);border-color:rgb(0,173,187);}/*!sc*/
# .hOmnBy .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(0,120,130);}/*!sc*/
# .hOmnBy[class~='hover'],.hOmnBy:hover{color:rgb(0,120,130);background-color:rgb(224,247,248);border-color:rgb(0,120,130);}/*!sc*/
# .hOmnBy[class~='hover'] .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path,.hOmnBy:hover .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(0,120,130);}/*!sc*/
# .hOmnBy[class~='focus'],.hOmnBy:focus{color:rgb(0,120,130);background-color:rgb(255,255,255);border-color:rgb(0,120,130);}/*!sc*/
# .hOmnBy[class~='focus'] .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path,.hOmnBy:focus .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(0,120,130);}/*!sc*/
# .hOmnBy[class~='active'],.hOmnBy:active{color:rgb(255,255,255);background-color:rgb(0,120,130);border-color:transparent;}/*!sc*/
# .hOmnBy[class~='active'] .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path,.hOmnBy:active .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(255,255,255);}/*!sc*/
# .hOmnBy[disabled]{color:rgb(205,209,212);background-color:rgb(245,246,247);border-color:rgb(205,209,212);}/*!sc*/
# .hOmnBy[disabled] .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(205,209,212);}/*!sc*/
# data-styled.g175[id="SecondaryButton-sc-12z1yri-0"]{content:"hOmnBy,"}/*!sc*/
# .jFdVct{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;}/*!sc*/
# .jFdVct > .ButtonBase-c2s2ot-0{box-shadow:none;margin:0;}/*!sc*/
# .jFdVct > .ButtonBase-c2s2ot-0:not(:first-child){border-top-left-radius:0;border-bottom-left-radius:0;}/*!sc*/
# .jFdVct > .ButtonBase-c2s2ot-0:not(:last-child){border-top-right-radius:0;border-bottom-right-radius:0;border-right:0;}/*!sc*/
# .jFdVct > .ButtonBase-c2s2ot-0:focus{border-right:1px solid;}/*!sc*/
# .jFdVct > .ButtonBase-c2s2ot-0:focus + .ButtonBase-c2s2ot-0{border-left:0;}/*!sc*/
# .jFdVct > .PrimaryButton-sc-2em7ay-0:focus{border-right:1px solid;}/*!sc*/
# .jFdVct > .PrimaryButton-sc-2em7ay-0:focus + .ButtonBase-c2s2ot-0{border-left:0;}/*!sc*/
# .jFdVct > .PrimaryButton-sc-2em7ay-0:hover{border-right:1px solid;color:rgb(255,255,255);background-color:rgb(0,120,130);}/*!sc*/
# .jFdVct > .PrimaryButton-sc-2em7ay-0:hover + .ButtonBase-c2s2ot-0{border-left:0;}/*!sc*/
# .jFdVct > .PrimaryButton-sc-2em7ay-0:hover .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(255,255,255);}/*!sc*/
# .jFdVct > .TertiaryButton-sc-1qjx54x-0:focus{border-right:1px solid;}/*!sc*/
# .jFdVct > .TertiaryButton-sc-1qjx54x-0:focus + .ButtonBase-c2s2ot-0{border-left:0;}/*!sc*/
# .jFdVct > .TertiaryButton-sc-1qjx54x-0:hover{border-right:1px solid;color:rgb(255,255,255);background-color:rgb(217,60,35);}/*!sc*/
# .jFdVct > .TertiaryButton-sc-1qjx54x-0:hover + .ButtonBase-c2s2ot-0{border-left:0;}/*!sc*/
# .jFdVct > .TertiaryButton-sc-1qjx54x-0:hover .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(255,255,255);}/*!sc*/
# .jFdVct > .PrimaryButton-sc-2em7ay-0 + .ButtonBase-c2s2ot-0,.jFdVct > .TertiaryButton-sc-1qjx54x-0 + .ButtonBase-c2s2ot-0,.jFdVct > [enabled='1'] + .ButtonBase-c2s2ot-0{border-left-color:transparent;}/*!sc*/
# data-styled.g182[id="ButtonGroup-bkavsp-0"]{content:"jFdVct,"}/*!sc*/
# .bwSnUp{font-size:16px;color:rgb(134,144,153);font-weight:normal;margin:0;padding-bottom:8px;}/*!sc*/
# data-styled.g247[id="SearchResultsHeadings__ResultCountText-sc-5g7okg-1"]{content:"bwSnUp,"}/*!sc*/
# .knKNvq{-webkit-flex:1 1 auto;-ms-flex:1 1 auto;flex:1 1 auto;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;padding:16px;padding-left:calc(16px + env(safe-area-inset-left));}/*!sc*/
# @media (max-width:47.9375em){.knKNvq{padding-right:calc(16px + env(safe-area-inset-right));}}/*!sc*/
# data-styled.g248[id="SearchResultsList__Container-sc-183kqex-0"]{content:"knKNvq,"}/*!sc*/
# .fznkpH{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;padding-bottom:8px;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-flex:1 1 auto;-ms-flex:1 1 auto;flex:1 1 auto;}/*!sc*/
# @media (max-width:62em){.fznkpH{-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}}/*!sc*/
# @media screen and (-ms-high-contrast:active),(-ms-high-contrast:none){.fznkpH{overflow:auto;}}/*!sc*/
# .fznkpH .TextPlaceholder-w2p5np-2{-webkit-flex:1 1 auto;-ms-flex:1 1 auto;flex:1 1 auto;}/*!sc*/
# data-styled.g249[id="SearchResultsList__HeadingContainer-sc-183kqex-1"]{content:"fznkpH,"}/*!sc*/
# .jLNYlr{width:100%;-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;display:block;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;-webkit-flex-basis:auto;-ms-flex-preferred-size:auto;flex-basis:auto;padding-bottom:16px;}/*!sc*/
# @media (min-width:376px){.jLNYlr{width:100%;}}/*!sc*/
# @media (min-width:570px){.jLNYlr{width:50%;}}/*!sc*/
# @media (min-width:768px){.jLNYlr{width:100%;}}/*!sc*/
# @media (min-width:993px){.jLNYlr{width:50%;}}/*!sc*/
# @media (min-width:1440px){.jLNYlr{width:33.33333%;}}/*!sc*/
# @media (min-width:2160px){.jLNYlr{width:25%;}}/*!sc*/
# data-styled.g250[id="SearchResultsList__WideCell-sc-183kqex-2"]{content:"jLNYlr,"}/*!sc*/
# .bwlcYL{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:100%;}/*!sc*/
# data-styled.g251[id="SearchResultsList__ResultCountContainer-sc-183kqex-3"]{content:"bwlcYL,"}/*!sc*/
# .bpESQu{margin:0;border-radius:8px;border-width:1px;border-style:solid;cursor:pointer;display:inline-block;color:rgb(59,65,68);text-align:center;font-weight:bold;-webkit-transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;white-space:nowrap;font-size:16px;line-height:1.5;padding:8px 16px;color:rgb(255,255,255);background-color:rgb(0,120,130);border-color:transparent;box-shadow:0px 8px 20px -15px rgba(59,65,68,0.7);margin-bottom:16px;width:32px;height:32px;padding:0;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;box-shadow:0 8px 16px 0 rgba(134,144,153,0.18),0 2px 4px 0 rgba(59,65,68,0.05);}/*!sc*/
# .bpESQu path{-webkit-transition:fill 0.1s;transition:fill 0.1s;}/*!sc*/
# .bpESQu .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:24px;width:24px;}/*!sc*/
# .bpESQu::-moz-focus-inner{border:0;}/*!sc*/
# .bpESQu[class~='focus'],.bpESQu:focus{outline:none;}/*!sc*/
# .bpESQu[disabled]{cursor:none;pointer-events:none;}/*!sc*/
# .bpESQu .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(255,255,255);}/*!sc*/
# .bpESQu[class~='hover'],.bpESQu:hover{color:rgb(0,120,130);background-color:rgb(255,255,255);border-color:rgb(0,120,130);}/*!sc*/
# .bpESQu[class~='hover'] .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path,.bpESQu:hover .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(0,120,130);}/*!sc*/
# .bpESQu[class~='focus'],.bpESQu:focus{color:rgb(0,120,130);background-color:rgb(224,247,248);border-color:rgb(0,120,130);}/*!sc*/
# .bpESQu[class~='focus'] .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path,.bpESQu:focus .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(0,120,130);}/*!sc*/
# .bpESQu[class~='active'],.bpESQu:active{color:rgb(255,255,255);background-color:rgb(0,120,130);border-color:transparent;box-shadow:none;}/*!sc*/
# .bpESQu[class~='active'] .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path,.bpESQu:active .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(255,255,255);}/*!sc*/
# .bpESQu[disabled]{color:rgb(205,209,212);background-color:rgb(245,246,247);border-color:rgb(205,209,212);box-shadow:none;}/*!sc*/
# .bpESQu[disabled] .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(205,209,212);}/*!sc*/
# data-styled.g253[id="PaginationButton__PaginationCarouselButton-cmg92v-0"]{content:"bpESQu,"}/*!sc*/
# .hURwqX{margin:0;border-radius:8px;border-width:1px;border-style:solid;cursor:pointer;display:inline-block;color:rgb(59,65,68);text-align:center;font-weight:bold;-webkit-transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;white-space:nowrap;font-size:16px;line-height:1.5;padding:8px 16px;width:32px;max-width:32px;height:32px;max-height:32px;padding:0;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:rgb(0,120,130);background-color:rgb(255,255,255);border-color:rgb(0,120,130);box-shadow:0 8px 16px 0 rgba(134,144,153,0.18),0 2px 4px 0 rgba(59,65,68,0.05);margin-bottom:16px;}/*!sc*/
# .hURwqX path{-webkit-transition:fill 0.1s;transition:fill 0.1s;}/*!sc*/
# .hURwqX .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:24px;width:24px;}/*!sc*/
# .hURwqX::-moz-focus-inner{border:0;}/*!sc*/
# .hURwqX[class~='focus'],.hURwqX:focus{outline:none;}/*!sc*/
# .hURwqX[disabled]{cursor:none;pointer-events:none;}/*!sc*/
# .hURwqX .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(0,120,130);}/*!sc*/
# .hURwqX[class~='hover'],.hURwqX:hover{background-color:rgb(224,247,248);}/*!sc*/
# .hURwqX[class~='focus'],.hURwqX:focus{background-color:rgb(232,233,234);}/*!sc*/
# .hURwqX[class~='active'],.hURwqX:active{background-color:rgb(255,255,255);}/*!sc*/
# .hURwqX[disabled]{color:rgb(205,209,212);background-color:rgb(245,246,247);border-color:rgb(205,209,212);box-shadow:none;}/*!sc*/
# .hURwqX[disabled] .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(205,209,212);}/*!sc*/
# .sSOJx{margin:0;border-radius:8px;border-width:1px;border-style:solid;cursor:pointer;display:inline-block;color:rgb(59,65,68);text-align:center;font-weight:bold;-webkit-transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;white-space:nowrap;font-size:16px;line-height:1.5;padding:8px 16px;width:32px;max-width:32px;height:32px;max-height:32px;padding:0;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:rgb(0,120,130);background-color:rgb(224,247,248);border-color:transparent;box-shadow:none;}/*!sc*/
# .sSOJx path{-webkit-transition:fill 0.1s;transition:fill 0.1s;}/*!sc*/
# .sSOJx .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:24px;width:24px;}/*!sc*/
# .sSOJx::-moz-focus-inner{border:0;}/*!sc*/
# .sSOJx[class~='focus'],.sSOJx:focus{outline:none;}/*!sc*/
# .sSOJx[disabled]{cursor:none;pointer-events:none;}/*!sc*/
# .sSOJx .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(0,120,130);}/*!sc*/
# .sSOJx[class~='hover'],.sSOJx:hover{background-color:rgb(232,233,234);border-color:transprant;}/*!sc*/
# .sSOJx[class~='focus'],.sSOJx:focus{background-color:rgb(224,247,248);border-color:rgb(205,209,212);}/*!sc*/
# .sSOJx[class~='active'],.sSOJx:active{background-color:rgb(224,247,248);border-color:transparent;}/*!sc*/
# .sSOJx[disabled]{color:rgb(205,209,212);background-color:rgb(245,246,247);border-color:rgb(205,209,212);box-shadow:none;}/*!sc*/
# .sSOJx[disabled] .getUiSvgContainer__SvgContainer-sc-12y8qp5-0 path{fill:rgb(205,209,212);}/*!sc*/
# data-styled.g254[id="PaginationButton-cmg92v-1"]{content:"hURwqX,sSOJx,"}/*!sc*/
# .bzIFjm{margin:32px 0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g255[id="SearchResultsPagination__Container-sc-1g9fbhd-0"]{content:"bzIFjm,"}/*!sc*/
# .cCOBPJ{margin-bottom:8px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .cCOBPJ li{margin:0;font-size:0;}/*!sc*/
# .cCOBPJ li+li{padding-left:4px;}/*!sc*/
# .cCOBPJ .PaginationButton__PaginationCarouselButton-cmg92v-0,.cCOBPJ .PaginationButton-cmg92v-1{margin-bottom:0;}/*!sc*/
# data-styled.g256[id="SearchResultsPagination__PageLinkList-sc-1g9fbhd-1"]{content:"cCOBPJ,"}/*!sc*/
# .kLoDJL{position:absolute;border-color:transparent;box-shadow:0 2px 4px rgba(59,65,68,0.2);margin-bottom:8px;margin-bottom:calc(8px + env(safe-area-inset-bottom));position:fixed;bottom:0;left:50%;-webkit-transform:translateX(-50%);-ms-transform:translateX(-50%);transform:translateX(-50%);-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;display:none;}/*!sc*/
# @media (max-width:47.9375em){.kLoDJL{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}}/*!sc*/
# data-styled.g270[id="SearchResultsFloatingNavigation__Container-sc-1frw5ws-0"]{content:"kLoDJL,"}/*!sc*/
# .dJgURm{margin:0;border-radius:8px;border-width:1px;border-style:solid;cursor:pointer;display:inline-block;color:rgb(59,65,68);text-align:center;font-weight:bold;-webkit-transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;transition:top 0.1s,box-shadow 0.1s,border-color 0.1s,background-color 0.1s,color 0.1s;white-space:nowrap;font-size:16px;line-height:1.5;padding:8px 16px;color:rgb(59,65,68);background-color:rgb(255,255,255);border-color:rgb(205,209,212);margin:0;border-top:none;border-bottom:none;border-right:none;}/*!sc*/
# .dJgURm path{-webkit-transition:fill 0.1s;transition:fill 0.1s;}/*!sc*/
# .dJgURm .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:24px;width:24px;}/*!sc*/
# .dJgURm::-moz-focus-inner{border:0;}/*!sc*/
# .dJgURm[class~='focus'],.dJgURm:focus{outline:none;}/*!sc*/
# .dJgURm[disabled]{cursor:none;pointer-events:none;}/*!sc*/
# .dJgURm:hover,.dJgURm[class~='hover']{color:rgb(59,65,68);background-color:rgb(232,233,234);border-color:transparent;}/*!sc*/
# .dJgURm[class~='focus'],.dJgURm:focus{color:rgb(59,65,68);background-color:rgb(255,255,255);border-color:rgb(134,144,153);}/*!sc*/
# .dJgURm[class~='active'],.dJgURm:active{color:rgb(255,255,255);background-color:rgb(134,144,153);border-color:transparent;}/*!sc*/
# ...
# .cdjWmp{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:1 0 auto;-ms-flex:1 0 auto;flex:1 0 auto;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# data-styled.g322[id="SearchResultsContentLayout__Container-sc-15fhfe9-1"]{content:"cdjWmp,"}/*!sc*/
# .bQquVY{width:50%;position:relative;display:block;-webkit-flex:1;-ms-flex:1;flex:1;}/*!sc*/
# @media (max-width:47.9375em){.bQquVY{width:100%;display:block;}}/*!sc*/
# data-styled.g323[id="SearchResultsContentLayout__ResultColumn-sc-15fhfe9-2"]{content:"bQquVY,"}/*!sc*/
# .brhyla{width:calc(50% - 16px);position:fixed;right:0;bottom:0;top:138px;height:calc(100vh - 154px);margin:0 16px 16px 0;border-radius:8px;touch-action:manipulation;-webkit-transform:translate3d(0px,0px,0px);-webkit-mask-image:-webkit-radial-gradient(white,black);}/*!sc*/
# @media (max-width:47.9375em){.brhyla{width:100%;height:calc(100vh - 138px);margin:0;border-radius:0;display:none;-webkit-transform:none;-webkit-mask-image:none;}}/*!sc*/
# .branch-banner-is-active .brhyla{top:214px;}/*!sc*/
# @media (max-width:47.9375em){.branch-banner-is-active .brhyla{height:calc(100vh - 214px);}}/*!sc*/
# data-styled.g324[id="SearchResultsContentLayout__MapColumn-sc-15fhfe9-3"]{content:"brhyla,"}/*!sc*/
# .eAeWYX{padding:16px;padding-top:0;}/*!sc*/
# @media (max-width:47.9375em){.eAeWYX{padding-right:0;}}/*!sc*/
# data-styled.g325[id="SearchResultsContentLayout__FooterContainer-sc-15fhfe9-4"]{content:"eAeWYX,"}/*!sc*/
# @font-face{font-family:"TruliaSans";src: url("https://www.trulia.com/images/fonts/TruliaSans_20190627/TruliaSansWeb-Regular.woff2") format("woff2"), url("https://www.trulia.com/images/fonts/TruliaSans_20190627/TruliaSansWeb-Regular.woff") format("woff");font-weight:400;font-style:normal;font-display:swap;}/*!sc*/
# @font-face{font-family:"TruliaSans";src: url("https://www.trulia.com/images/fonts/TruliaSans_20190627/TruliaSansWeb-Bold.woff2") format("woff2"), url("https://www.trulia.com/images/fonts/TruliaSans_20190627/TruliaSansWeb-Bold.woff") format("woff");font-weight:600;font-style:normal;font-display:swap;}/*!sc*/
# html,body{margin:0;padding:0;font-family:'TruliaSans',system,-apple-system,Roboto,Segoe UI Bold,Arial,sans-serif;color:rgb(59,65,68);background-color:rgb(255,255,255);font-size:16px;line-height:1.5;-webkit-letter-spacing:-.1px;-moz-letter-spacing:-.1px;-ms-letter-spacing:-.1px;letter-spacing:-.1px;}/*!sc*/
# html .getUiSvgContainer__SvgContainer-sc-12y8qp5-0,body .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:24px;width:24px;}/*!sc*/
# *{box-sizing:border-box;}/*!sc*/
# ::-moz-focus-inner{border:0;}/*!sc*/
# a{color:rgb(0,120,130);-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# ul{margin:0;padding:0;list-style:none;}/*!sc*/
# h1,h2,h3,h4,h5,h6{margin-top:0;margin-bottom:8px;}/*!sc*/
# h1{font-size:28px;}/*!sc*/
# h2{font-size:24px;}/*!sc*/
# h3{font-size:20px;}/*!sc*/
# h4{font-size:16px;}/*!sc*/
# h5{font-size:14px;}/*!sc*/
# h6{font-size:12px;}/*!sc*/
# input,button,textarea{font-family:'TruliaSans',system,-apple-system,Roboto,Segoe UI Bold,Arial,sans-serif;font-size:16px;line-height:1.5;}/*!sc*/
# input .getUiSvgContainer__SvgContainer-sc-12y8qp5-0,button .getUiSvgContainer__SvgContainer-sc-12y8qp5-0,textarea .getUiSvgContainer__SvgContainer-sc-12y8qp5-0{height:24px;width:24px;}/*!sc*/
# .modalActive{overflow:hidden !important;max-height:100%;}/*!sc*/
# data-styled.g378[id="sc-global-ljJzTe1"]{content:"sc-global-ljJzTe1,"}/*!sc*/
# </style><script>
#               new Image().src = "/track/trackingPixel.gif?lifetimeID=201208ql06dofecc7eamhb836aoum757&abTests=1262a;1264a;1267b;1268b;1270a;1271_control;1272_control;1273a;1274a&requestID=L2W2iupE4ghjcyvfz4ZM3fNf9Q0hchWKTiWCqls8dq9cf_VJGVZYOQ=="
#           </script><script>
#         (function(b,r,a,n,c,h,_,s,d,k){if(!b[n]||!b[n]._q){for(;s<_.length;)c(h,_[s++]);d=r.createElement(a);d.async=1;d.src="https://cdn.branch.io/branch-latest.min.js";k=r.getElementsByTagName(a)[0];k.parentNode.insertBefore(d,k);b[n]=h}})(window,document,"script","branch",function(b,r){b[r]=function(){b._q.push([r,arguments])}},{_q:[],_v:1},"addListener applyCode autoAppIndex banner closeBanner closeJourney creditHistory credits data deepview deepviewCta first getCode init link logout redeem referrals removeListener sendSMS setBranchViewData setIdentity track validateCode trackCommerceEvent logEvent disableTracking".split(" "), 0);
#         branch.init("key_live_pkrocc5yGCN4njTWV2CmGlapwtfdRBt8", {"metadata":{"page":"srp","pageType":"for-rent-srp"},"isDirectVisit":"1"});
#         branch.setBranchViewData({"data":{"city":"San Diego","state":"CA"}});
#       </script><script async="" src="//js-sec.indexww.com/ht/htw-trulia.js"></script><meta charset="utf-8"/><title>Apartments For Rent in San Diego, CA - 2,283 Rentals | Trulia</title><meta content="Search 2,283 Rental Properties in San Diego, California. Find San Diego apartments, condos, town homes, single family homes and much more on Trulia." name="description"/><meta content="width=device-width, initial-scale=1.0, maximum-scale=5.0, viewport-fit=cover, minimal-ui" name="viewport"/><meta content="5953837487" property="fb:admins"/><meta content="183577541666001" property="fb:app_id"/><meta content="Trulia" property="application-name"/><meta content="https://www.trulia.com" property="msapplication-starturl"/><meta content="Trulia: Real Estate Search" property="msapplication-tooltip"/><meta content="/browserconfig.xml" property="msapplication-config"/><meta content="en_US" property="og:locale"/><meta content="Trulia Real Estate Search" property="og:site_name"/><meta content="website" property="og:type"/><meta content="@trulia" property="twitter:site"/><meta content="yes" property="mobile-web-app-capable"/><meta content="#ffffff" property="theme-color"/><meta content="yes" property="apple-mobile-web-app-capable"/><link href="https://assets.adobedtm.com" rel="preconnect"/><link href="https://maps.googleapis.com" rel="preconnect"/><link href="https://collector-PXYO6YjwLb.px-cloud.net" rel="preconnect"/><link href="https:///static.trulia-cdn.com" rel="preconnect"/><link href="https://assets.adobedtm.com" rel="dns-prefetch"/><link href="https://maps.googleapis.com" rel="dns-prefetch"/><link href="https://collector-PXYO6YjwLb.px-cloud.net" rel="dns-prefetch"/><link href="https:///static.trulia-cdn.com" rel="dns-prefetch"/><link href="/manifest" rel="manifest"/><link href="//www.trulia.com/images/icons/app/app-icon-120.png" rel="apple-touch-icon-precomposed"/><link href="//www.trulia.com/images/icons/app/app-icon-144.png" rel="apple-touch-icon-precomposed" sizes="144x144"/><link href="//www.trulia.com/images/icons/app/app-icon-152.png" rel="apple-touch-icon-precomposed" sizes="152x152"/><link href="//www.trulia.com/images/icons/app/app-icon-180.png" rel="apple-touch-icon-precomposed" sizes="180x180"/><link href="//www.trulia.com/images/icons/app/app-icon-196.png" rel="shortcut icon" sizes="196x196"/><link href="//www.trulia.com/images/icons/favicon-rebrand-128.png" rel="icon" sizes="120x120"/><link href="//www.trulia.com/images/icons/favicon-rebrand-196.png" rel="icon" sizes="196x196"/><link href="//www.trulia.com/images/icons/app/app-icon-228.png" rel="icon" sizes="228x228"/><link color="#00ADBB" href="//www.trulia.com/images/icons/mask-icon.svg" rel="mask-icon"/><meta content="INDEX, FOLLOW" name="robots"/><meta content="https://www.trulia.com/for_rent/San_Diego,CA/" property="og:url"/><meta content="Search 2,283 Rental Properties in San Diego, California. Find San Diego apartments, condos, town homes, single family homes and much more on Trulia." property="og:description"/><meta content="Apartments For Rent in San Diego, CA - 2,283 Rentals | Trulia" property="og:title"/><meta content="https://www.trulia.com/images/logos/standardized/v4/logo-with-icon-200x200.png" property="og:image"/><meta content="200" property="og:image:width"/><meta content="200" property="og:image:height"/><link href="android-app://com.trulia.android/https/www.trulia.com/for_rent/San_Diego,CA/" rel="alternate"/><link href="ios-app://288487321/https/www.trulia.com/for_rent/San_Diego,CA/" rel="alternate"/><link href="https://www.trulia.com/for_rent/San_Diego,CA/" rel="canonical"/><link href="https://www.trulia.com/for_rent/San_Diego,CA/2_p/" rel="next"/><meta content="46" name="next-head-count"/></head><body><div id="__next"><div class="SearchResultsHeader__HeaderContainer-sc-1n45ts4-0 lprqrI" data-testid="search-results-header"><nav class="Navbar__Nav-sky7mr-0 eAlroL"><a aria-label="Go to Trulia Home" class="Navbar__LogoContainer-sky7mr-2 lmeUPp" href="/rent/" ...
#       if (
#         window.performance &&
#         window.performance.mark &&
#         window.performance.measure
#       ) {
#         var cards = document.querySelectorAll('[data-hero-element-id="srp-home-card"]');
#         var loadedImages = [];
#
#         for (var i = 0; i < cards.length; i++) {
#           var image = cards[i].querySelector('img');
#           if (image.complete) {
#             loadedImages.push(Promise.resolve(image));
#           } else {
#             loadedImages.push(
#               new Promise(function (accept) {
#                 image.addEventListener('load', function () {
#                   accept(this);
#                 });
#               })
#             );
#           }
#         }
#
#         Promise.all(loadedImages).then(function() {
#           window.performance.mark('hero_image_load_end');
#           window.performance.measure('hero_image_load');
#
#           performance.clearMarks('hero_element_displayed');
#           performance.mark('hero_element_displayed');
#         });
#       }
#     </script></div></div><div class="SearchResultsPagination__Container-sc-1g9fbhd-0 bzIFjm" data-testid="search-results-pagination"><ul aria-label="Pagination Navigation" class="List__ListContainer-sc-1mezygb-0 kgdOJe SearchResultsPagination__PageLinkList-sc-1g9fbhd-1 cCOBPJ"><li data-testid="pagination-page-link"><a aria-current="page" aria-label="Page 1" class="ButtonBase-c2s2ot-0 PaginationButton-cmg92v-1 hURwqX" href="/for_rent/San_Diego,CA/">1</a></li><li data-testid="pagination-page-link"><a aria-label="Page 2" class="ButtonBase-c2s2ot-0 PaginationButton-cmg92v-1 sSOJx" href="/for_rent/San_Diego,CA/2_p/">2</a></li><li data-testid="pagination-page-link"><a aria-label="Page 3" class="ButtonBase-c2s2ot-0 PaginationButton-cmg92v-1 sSOJx" href="/for_rent/San_Diego,CA/3_p/">3</a></li><li aria-hidden="true" data-testid="pagination-ellipses"><div class="Text__TextBase-sc-1i9uasc-0-div Text__TextContainerBase-sc-1i9uasc-1 cKVrTx">…</div></li><li data-testid="pagination-page-link"><a aria-label="Page 75" class="ButtonBase-c2s2ot-0 PaginationButton-cmg92v-1 sSOJx" href="/for_rent/San_Diego,CA/75_p/">75</a></li><li data-testid="pagination-page-link"><a aria-label="Page 76" class="ButtonBase-c2s2ot-0 PaginationButton-cmg92v-1 sSOJx" href="/for_rent/San_Diego,CA/76_p/">76</a></li><li data-testid="pagination-page-link"><a aria-label="Page 77" class="ButtonBase-c2s2ot-0 PaginationButton-cmg92v-1 sSOJx" href="/for_rent/San_Diego,CA/77_p/">77</a></li><li data-testid="pagination-next-page"><a aria-label="Next Page" class="ButtonBase-c2s2ot-0 PrimaryButton-sc-2em7ay-0 PaginationButton__PaginationCarouselButton-cmg92v-0 bpESQu" href="/for_rent/San_Diego,CA/2_p/" rel="next"><div class="getUiSvgContainer__SvgContainer-sc-12y8qp5-0 BCzkn"><svg class="svg" viewbox="0 0 32 32" xmlns="http://www.w3.org/2000/svg"><path d="M17.65 16.513l-7.147-7.055 1.868-1.893 9.068 8.951-9.069 8.927-1.866-1.896z" fill="#869099"></path></svg></div></a></li></ul><div class="Text__TextBase-sc-1i9uasc-0-div Text__TextContainerBase-sc-1i9uasc-1 AuUdo" data-testid="pagination-caption">1-30 of 2,283 Results</div></div><div class="Padding-sc-1d43y5s-0 knveJa"><script data-testid="srp-seo-breadcrumbs-list" type="application/ld+json">{"@context":"http://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"item":{"@id":"/rent-sitemap/","name":"United States"}},{"@type":"ListItem","position":2,"item":{"@id":"/rent-sitemap/California-apartments/","name":"California"}}]}</script><nav class="Breadcrumb__BreadcrumbContainer-sc-1xyrxr-0 hOQbAV SearchResultsBreadcrumbs__CenteredBreadcrumbs-al7i2i-0 hQKtUB"><div class="Padding-sc-1d43y5s-0 hHdjtD" r="xxs"><div class="MediaBlock__MediaContainer-ldzu2c-0 ilIDoN"><div class="MediaBlock__MediaContent-ldzu2c-1 eOdfXT"><span class="Text__TextBase-sc-1i9uasc-0 hpggbg"><a href="/rent-sitemap/">United States</a></span></div><div class="getUiSvgContainer__SvgContainer-sc-12y8qp5-0 gbHoxB"><svg class="svg" viewbox="0 0 32 32" xmlns="http://www.w3.org/2000/svg"><path d="M17.65 16.513l-7.147-7.055 1.868-1.893 9.068 8.951-9.069 8.927-1.866-1.896z" fill="#869099"></path></svg></div></div></div><div class="Padding-sc-1d43y5s-0 hHdjtD" r="xxs"><div class="MediaBlock__MediaContainer-ldzu2c-0 ilIDoN"><div class="MediaBlock__MediaContent-ldzu2c-1 eOdfXT"><span class="Text__TextBase-sc-1i9uasc-0 hpggbg"><a href="/rent-sitemap/California-apartments/">California</a></span></div><div class="getUiSvgContainer__SvgContainer-sc-12y8qp5-0 gbHoxB"><svg class="svg" viewbox="0 0 32 32" xmlns="http://www.w3.org/2000/svg"><path d="M17.65 16.513l-7.147-7.055 1.868-1.893 9.068 8.951-9.069 8.927-1.866-1.896z" fill="#869099"></path></svg></div></div></div><div class="Padding-sc-1d43y5s-0 hHdjtD" r="xxs"><div class="MediaBlock__MediaContainer-ldzu2c-0 ilIDoN"><div class="MediaBlock__MediaContent-ldzu2c-1 eOdfXT"><span class="Text__TextBase-sc-1i9uasc-0 hpggbg"><span>San Diego</span></span></div></div></div></nav></div><div><div><div ...
#           function initTracking(pageviewPayload) {
#     window.s = window.s || {};
#     window.trulia = window.trulia || {};
#     window.trulia.dataLayer = window.trulia.dataLayer || {};
#     window.trulia.dataLayer.referrer = document.referrer;
#
#     function listenersDefined() {
#       const listeners = window.trulia.dataLayer.listeners;
#       return typeof listeners !== 'undefined' && listeners.length !== 0;
#     }
#
#     const queue = [];
#
#     const track = function (event, data, isInitialPageView) {
#       if (processQueue()) {
#         handleEvent(event, data, isInitialPageView);
#       } else {
#         queue.push({
#           event: event,
#           data: data,
#           isInitialPageView: isInitialPageView
#         });
#       }
#     };
#
#     const handleEvent = function (event, data, isInitialPageView) {
#       if (isInitialPageView) {
#         window.s.referrer = window.trulia.dataLayer.referrer;
#       }
#
#       trulia.dataLayer.listeners.forEach(function (listener) {
#         listener(event, data);
#       });
#     };
#
#     const processQueue = function () {
#       if (listenersDefined()) {
#         if (queue.length) {
#           let queuedData;
#
#           while (queuedData = queue.shift()) {
#             handleEvent(queuedData.event, queuedData.data, queuedData.isInitialPageView);
#           }
#         }
#
#         return true;
#       }
#
#       setTimeout(processQueue, 300);
#       return false;
#     };
#
#     if (pageviewPayload) {
#       track('trackState', pageviewPayload, true);
#     }
#
#     window.trulia.dataLayer.track = track;
#   }
#           initTracking(null);
#         </script><script>
#             (function() {
#                 window._pxAppId = 'PXYO6YjwLb';
#                 // Custom parameters
#                 // window._pxParam1 = "<param1>";
#                 var p = document.getElementsByTagName('script')[0],
#                     s = document.createElement('script');
#                 s.async = 1;
#                 s.src = '//client.px-cloud.net/PXYO6YjwLb/main.min.js';
#                 p.parentNode.insertBefore(s, p);
#             }());
#             </script><noscript><div height="1" style="position:fixed;top:0;left:0;display:none" width="1"><img alt="px pixel" src="//collector-PXYO6YjwLb.px-cloud.net/api/v1/collector/noScript.gif?appId=PXYO6YjwLb"/></div></noscript></body></html>

# %%
# print(BS.prettify())

# %%
# html = requests.get(
#     'https://www.trulia.com/for_rent/San_Diego,CA/=').text
bs = BS(url)
possible_links = bs.find_all('a')
for link in possible_links:
    if link.has_attr('href'):
        print(link.attrs['href'])
# Out:
# C:\Users\nickf\anaconda3\lib\site-packages\bs4\__init__.py:414: MarkupResemblesLocatorWarning: "https://www.trulia.com/for_rent/San_Diego,CA/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
